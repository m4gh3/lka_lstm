# %%
# For tips on running notebooks in Google Colab, see
# https://pytorch.org/tutorials/beginner/colab
# %matplotlib inline

# %% [markdown]
# ## (Tutorial stolen and adapted to LKA_LSTM)
#
# # Language Modeling with ``LKA_LSTM`` and torchtext
#
# This is a tutorial on training a model to predict the next word in a sequence using the
# [nn.Transformer](https://pytorch.org/docs/stable/generated/torch.nn.Transformer.html)_ module.
#
# The PyTorch 1.2 release includes a standard transformer module based on the
# paper [Attention is All You Need](https://arxiv.org/pdf/1706.03762.pdf)_.
# Compared to Recurrent Neural Networks (RNNs), the transformer model has proven
# to be superior in quality for many sequence-to-sequence tasks while being more
# parallelizable. The ``nn.Transformer`` module relies entirely on an attention
# mechanism (implemented as
# [nn.MultiheadAttention](https://pytorch.org/docs/stable/generated/torch.nn.MultiheadAttention.html)_)
# to draw global dependencies between input and output. The ``nn.Transformer``
# module is highly modularized such that a single component (e.g.,
# [nn.TransformerEncoder](https://pytorch.org/docs/stable/generated/torch.nn.TransformerEncoder.html)_)
# can be easily adapted/composed.
#
# <img src="file://../_static/img/transformer_architecture.jpg">

# %% [markdown]
# ## Define the model

# %% [markdown]
# In this tutorial, we train a ``nn.TransformerEncoder`` model on a
# causal language modeling task. Please note that this tutorial does not cover
# the training of [nn.TransformerDecoder](https://pytorch.org/docs/stable/generated/torch.nn.TransformerDecoder.html#torch.nn.TransformerDecoder)_, as depicted in
# the right half of the diagram above. The language modeling task is to assign a
# probability for the likelihood of a given word (or a sequence of words)
# to follow a sequence of words. A sequence of tokens are passed to the embedding
# layer first, followed by a positional encoding layer to account for the order
# of the word (see the next paragraph for more details). The
# ``nn.TransformerEncoder`` consists of multiple layers of
# [nn.TransformerEncoderLayer](https://pytorch.org/docs/stable/generated/torch.nn.TransformerEncoderLayer.html)_.
# Along with the input sequence, a square attention mask is required because the
# self-attention layers in ``nn.TransformerDecoder`` are only allowed to attend
# the earlier positions in the sequence. For the language modeling task, any
# tokens on the future positions should be masked.  This masking, combined with fact that
# the output embeddings are offset with later positions ensures that the
# predictions for position i can depend only on the known outputs at positions less than i.
# To produce a probability  distribution over output words, the output of the ``nn.TransformerEncoder``
# model is passed through a linear layer to output unnormalized logits.
# The log-softmax function isn't applied here due to the later use of
# [CrossEntropyLoss](https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html)_,
# which requires the inputs to be unnormalized logits.

# %%
import math
import os
from tempfile import TemporaryDirectory
from typing import Tuple

import torch
from torch import nn, Tensor
from torch.nn import TransformerEncoder, TransformerEncoderLayer
from torch.utils.data import dataset

from lka_lstm import LKA_LSTM_LM

# %% [markdown]
# ## Load and batch data

# %% [markdown]
# This tutorial uses ``torchtext`` to generate Wikitext-2 dataset.
# To access torchtext datasets, please install torchdata following instructions at https://github.com/pytorch/data.
# %%

# %% [raw]
# %%bash
# pip install portalocker
# pip install torchdata

# %% [markdown]
# The vocab object is built based on the train dataset and is used to numericalize
# tokens into tensors. Wikitext-2 represents rare tokens as `<unk>`.
#
# Given a 1-D vector of sequential data, ``batchify()`` arranges the data
# into ``batch_size`` columns. If the data does not divide evenly into
# ``batch_size`` columns, then the data is trimmed to fit. For instance, with
# the alphabet as the data (total length of 26) and ``batch_size=4``, we would
# divide the alphabet into sequences of length 6, resulting in 4 of such sequences.
#
# \begin{align}\begin{bmatrix}
#   \text{A} & \text{B} & \text{C} & \ldots & \text{X} & \text{Y} & \text{Z}
#   \end{bmatrix}
#   \Rightarrow
#   \begin{bmatrix}
#   \begin{bmatrix}\text{A} \\ \text{B} \\ \text{C} \\ \text{D} \\ \text{E} \\ \text{F}\end{bmatrix} &
#   \begin{bmatrix}\text{G} \\ \text{H} \\ \text{I} \\ \text{J} \\ \text{K} \\ \text{L}\end{bmatrix} &
#   \begin{bmatrix}\text{M} \\ \text{N} \\ \text{O} \\ \text{P} \\ \text{Q} \\ \text{R}\end{bmatrix} &
#   \begin{bmatrix}\text{S} \\ \text{T} \\ \text{U} \\ \text{V} \\ \text{W} \\ \text{X}\end{bmatrix}
#   \end{bmatrix}\end{align}
#
# Batching enables more parallelizable processing. However, batching means that
# the model treats each column independently; for example, the dependence of
# ``G`` and ``F`` can not be learned in the example above.

# %%
from wikidat import WikiText2
from torchtext.data.utils import get_tokenizer
from torchtext.vocab import build_vocab_from_iterator
from tokenizers import Tokenizer

#train_iter = WikiText2(split='train')
#tokenizer = get_tokenizer('basic_english')
#vocab = build_vocab_from_iterator(map(tokenizer, train_iter), specials=['<unk>'])
#vocab.set_default_index(vocab['<unk>'])
tokenizer = Tokenizer.from_file("en_wpiece.json")

def data_process(raw_text_iter: dataset.IterableDataset) -> Tensor:
    """Converts raw text into a flat Tensor."""
    data = [torch.tensor(tokenizer.encode(item).ids, dtype=torch.long) for item in raw_text_iter]
    return torch.cat(tuple(filter(lambda t: t.numel() > 0, data)))

# ``train_iter`` was "consumed" by the process of building the vocab,
# so we have to create it again
train_iter, val_iter, test_iter = WikiText2()
train_data = data_process(train_iter)
val_data = data_process(val_iter)
test_data = data_process(test_iter)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

def batchify(data: Tensor, bsz: int) -> Tensor:
    """Divides the data into ``bsz`` separate sequences, removing extra elements
    that wouldn't cleanly fit.

    Arguments:
        data: Tensor, shape ``[N]``
        bsz: int, batch size

    Returns:
        Tensor of shape ``[N // bsz, bsz]``
    """
    seq_len = data.size(0) // bsz
    data = data[:seq_len * bsz]
    data = data.view(bsz, seq_len) #.t().contiguous()
    return data.to(device)

batch_size = 20
eval_batch_size = 10
train_data = batchify(train_data, batch_size)  # shape ``[seq_len, batch_size]``
val_data = batchify(val_data, eval_batch_size)
test_data = batchify(test_data, eval_batch_size)

# %% [markdown]
# ### Functions to generate input and target sequence

# %% [markdown]
# ``get_batch()`` generates a pair of input-target sequences for
# the transformer model. It subdivides the source data into chunks of
# length ``bptt``. For the language modeling task, the model needs the
# following words as ``Target``. For example, with a ``bptt`` value of 2,
# we’d get the following two Variables for ``i`` = 0:
#
# <img src="file://../_static/img/transformer_input_target.png">
#
# It should be noted that the chunks are along dimension 0, consistent
# with the ``S`` dimension in the Transformer model. The batch dimension
# ``N`` is along dimension 1.

# %%
bptt = 512
def get_batch(source: Tensor, i: int) -> Tuple[Tensor, Tensor]:
    """
    Args:
        source: Tensor, shape ``[full_seq_len, batch_size]``
        i: int

    Returns:
        tuple (data, target), where data has shape ``[seq_len, batch_size]`` and
        target has shape ``[seq_len * batch_size]``
    """
    #print("src shape:", source.shape )
    #seq_len = min(bptt, len(source) - 1 - i)
    seq_len = min(bptt, source.shape[1] - 1 - i )
    #print("seq len: ", seq_len )
    data = source[:,i:i+seq_len]
    target = source[:,i+1:i+1+seq_len].reshape(-1)
    return data, target

# %% [markdown]
# ## Initiate an instance

# %% [markdown]
# The model hyperparameters are defined below. The ``vocab`` size is
# equal to the length of the vocab object.

# %%
ntokens = tokenizer.get_vocab_size() #len(vocab)  # size of vocabulary
print("vocab sz: ", ntokens )
emsize = 64 #200  # embedding dimension
d_hid =  8 #200  # dimension of the feedforward network model in ``nn.TransformerEncoder``
nlayers = 2  # number of ``nn.TransformerEncoderLayer`` in ``nn.TransformerEncoder``
nhead = 8 # number of heads in ``nn.MultiheadAttention``
dropout = 0.2  # dropout probability
model = LKA_LSTM_LM(ntokens, emsize, d_hid, nhead ).to(device) #TransformerModel(ntokens, emsize, nhead, d_hid, nlayers, dropout).to(device)
# Out:
# vocab sz:  2048

# %% [markdown]
# ## Run the model

# %% [markdown]
# We use [CrossEntropyLoss](https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html)_
# with the [SGD](https://pytorch.org/docs/stable/generated/torch.optim.SGD.html)_
# (stochastic gradient descent) optimizer. The learning rate is initially set to
# 5.0 and follows a [StepLR](https://pytorch.org/docs/stable/generated/torch.optim.lr_scheduler.StepLR.html)_
# schedule. During training, we use [nn.utils.clip_grad_norm\_](https://pytorch.org/docs/stable/generated/torch.nn.utils.clip_grad_norm_.html)_
# to prevent gradients from exploding.

# %%
import time

criterion = nn.CrossEntropyLoss()
lr = 0.01  # learning rate
optimizer = torch.optim.AdamW(model.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 1.0, gamma=0.95)

def train(model: nn.Module) -> None:
    model.train()  # turn on train mode
    total_loss = 0.
    log_interval = 50 #200
    start_time = time.time()

    num_batches = train_data.shape[1] // bptt
    #print("n batches:", num_batches )
    #print("train_shape: ", train_data.shape )
    for batch, i in enumerate(range(0, train_data.size(1) - 1, bptt)):
        data, targets = get_batch(train_data, i)
        output = model(data)
        output_flat = output.view(-1, ntokens)
        loss = criterion(output_flat, targets)

        optimizer.zero_grad()
        loss.backward()
        #torch.nn.utils.clip_grad_norm_(model.parameters(), 0.5)
        optimizer.step()

        total_loss += loss.item()
        if batch % log_interval == 0 and batch > 0:
            #lr = scheduler.get_last_lr()[0]
            ms_per_batch = (time.time() - start_time) * 1000 / log_interval
            cur_loss = total_loss / log_interval
            ppl = math.exp(min(cur_loss, 100 ))
            print(f'| epoch {epoch:3d} | {batch:5d}/{num_batches:5d} batches | '
                  f'loss {cur_loss:5.2f} | ppl {ppl:8.2f}')
            #f'lr {lr:02.2f} | ms/batch {ms_per_batch:5.2f} | '
            total_loss = 0
            start_time = time.time()

def evaluate(model: nn.Module, eval_data: Tensor) -> float:
    model.eval()  # turn on evaluation mode
    total_loss = 0.
    with torch.no_grad():
        for i in range(0, eval_data.size(1) - 1, bptt):
            data, targets = get_batch(eval_data, i)
            seq_len = data.size(1)
            output = model(data)
            output_flat = output.view(-1, ntokens)
            total_loss += seq_len * criterion(output_flat, targets).item()
            if i==0:
                out_ids = output.argmax(dim=-1)[0].cpu()
                print( tokenizer.decode(out_ids.numpy()).replace(' ##', '') )
    return total_loss / (eval_data.size(1) - 1)

# %% [markdown]
# Loop over epochs. Save the model if the validation loss is the best
# we've seen so far. Adjust the learning rate after each epoch.

# %%
best_val_loss = float('inf')
epochs = 200

with TemporaryDirectory() as tempdir:
    best_model_params_path = os.path.join(tempdir, "best_model_params.pt")

    for epoch in range(1, epochs + 1):
        epoch_start_time = time.time()
        train(model)
        val_loss = evaluate(model, val_data)
        val_ppl = math.exp(min(val_loss, 100 ))
        elapsed = time.time() - epoch_start_time
        print('-' * 89)
        print(f'| end of epoch {epoch:3d} | time: {elapsed:5.2f}s | '
            f'valid loss {val_loss:5.2f} | valid ppl {val_ppl:8.2f}')
        print('-' * 89)

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), best_model_params_path)

        #scheduler.step()
    model.load_state_dict(torch.load(best_model_params_path)) # load best model states
# Out:
# | epoch   1 |    50/  332 batches | loss  6.14 | ppl   463.62
# | epoch   1 |   100/  332 batches | loss  5.08 | ppl   160.03
# | epoch   1 |   150/  332 batches | loss  4.77 | ppl   117.96
# | epoch   1 |   200/  332 batches | loss  4.66 | ppl   106.07
# | epoch   1 |   250/  332 batches | loss  4.58 | ppl    97.17
# | epoch   1 |   300/  332 batches | loss  4.50 | ppl    90.24
# =ar and ,iansy . , =ar and ,iansy . , and as a <an <rite , < starrite , and a < of the unk > ,rite , the < <anticul 'n < anditectdctt , <r < of , the < <r the is aoser <ative the the < <rite , andoll the < , the is beth the <ntth of the th 0amby < 0 0 the , the <ive the thickitiesam , , < 9 0lack , the then of <ervolaflyira theosen , the the of the <rite , <uel and aing the .rite ,uc . theache the theern thered , the <m of ander theitheraa , was <ol to the <ale , the to the < , theirion of the the unk > ,ryana thearm ,iansy . , a <ly <im ,por toia , and the aider <ambt , therite ,et , and of < the < < a of the = =ription of = =arm ,iansy . , a <ly unk > , and the < ofntth of to the th 0ren , ( < 0 0 the , thearbo the to the th 1 0ickitiesam , , < 9 9 1 9 ,lack , the the <rite ,ambt , therite ,et , <ually the 0 0 1 0 ,amby 1 9 1 9 0 the ,er thearbo 0 . @ 5 0 0 0 . @ 5 0icka < 9 . @ 5 0 0 0 . @ 5 9lack , the the <ashra , , andrite , been <man unk > , was aretion wasge the to then the the < of the unk > , < unk > , , the was bered times , < , the <rite , and theisionad of , the thething 9 1 0 , therdals , the < downira the unk > , aed to the <r and a ofyn ,ult ,ira theosen , the <rd of a < < unk > , . and the been of to unk > , in theashed thepar , the < < a < <ambive
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 739.84s | valid loss  4.27 | valid ppl    71.34
# -----------------------------------------------------------------------------------------
# | epoch   2 |    50/  332 batches | loss  4.50 | ppl    89.84
# | epoch   2 |   100/  332 batches | loss  4.35 | ppl    77.26
# | epoch   2 |   150/  332 batches | loss  4.30 | ppl    73.90
# | epoch   2 |   200/  332 batches | loss  4.31 | ppl    74.39
# | epoch   2 |   250/  332 batches | loss  4.28 | ppl    72.38
# | epoch   2 |   300/  332 batches | loss  4.25 | ppl    70.20
# =ar , ,ainmy , , =ar , ,army , , and as a <an <rite , < starrite , and a < of the unk > ,rite , the < <antic coast 'n < anditessng , <r < of , the < prir the is aose to <ative to the < novelrite , andoll < novel is the is ben the <ngth of the 0 0ma < 0 0 the , < <ive the 0ickomeam , , < 9 0lack , the then of <istolateflyir , theosen . the the of the <rite of knownuen and aing the .rite ,uc . theache the theer thes , the 1mer of ande theitherna , was notried out the <ale of theper the < , theirionine the the unk > ,ryingna thearf isianmy and , a <ly <imedpor toood , and the aidely toelet , therite ,or . and of < the < and a of the = =ription of = =arf =army and , a <ly unk > , and the < ofntth . to the 0 0urn , ( < 0 0 the , <arbo the to the @ 1 0ilomeam , , < 9 9 1 9 )lack , and the <rite ofambt , therite ,or . <ually to 0 0 1 0 )ma < 5 1 9 ) the ,er <arbo 0 . @ 5 0 1 0 . @ 5 0il ) 1 9 . @ 5 0 1 ° . @ 5 0lack , the the <ashra , , therite , been <dge unk > , was areclionll to the to then and the 2 of the unk > , < unk > ) , the is bes times , < , theerrite , and theisionct , , the thething 9 1 0 , thelysals , the < downirs the unk > , aed to the <st and anyn ,ult ,ir , theosen . the <sts of a < < unk > , . and the beened to unk > , to theashing thepard the < bird a < <ambive
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 822.13s | valid loss  4.09 | valid ppl    59.47
# -----------------------------------------------------------------------------------------
# | epoch   3 |    50/  332 batches | loss  4.31 | ppl    74.33
# | epoch   3 |   100/  332 batches | loss  4.18 | ppl    65.40
# | epoch   3 |   150/  332 batches | loss  4.16 | ppl    63.85
# | epoch   3 |   200/  332 batches | loss  4.18 | ppl    65.32
# | epoch   3 |   250/  332 batches | loss  4.16 | ppl    64.12
# | epoch   3 |   300/  332 batches | loss  4.14 | ppl    62.79
# =arp ,ainsa , , =ar , ,ainia < , and as < <an <rite , < starrite , < a < of the unk > ,rite , the < <antic coastmn < <iassng , < , < of of the < <s the is aosely <ated to the < <rite , theoll <s , the is ben the <ngth of the 0 0ma 1 0 0 the , the < of the 0ilomeam , , < 9 0l ) , the then the <istolatedit .id , theosen . the the , the <rite of knownockn and theing the .rite ,uc . theachies the theer thes , the 1mer , ande theygth . was notried out the <ale , theper the < , theirra . the the unk > ,ryingna thearp isainmap , a <ly <imateded toood . and the aidely <atchter . therite ,or . andly < the 1 and a of the = =ription = = =ari isianmap , a <ly unk > , and the < ofngth . to the 0 @urn , ( < 0 0 the , thearbo the to the @ 1 0ilomeam , , < 9 9 1 9 )l ) , the the <rite ofambt , ther , ,or , <ually < 0 0 1 0 ,m ) 1 5 1 0 ) the ,er <arbo 0 . @ 5 0 1 0 . @ 5 0il ) 1 @ . @ 5 0 1 0 . @ 5 4b ) , the the <ashome , , therite are been <mge unk > , was arecllyllge the to then and the 1 of the unk > , < unk > ) , the is bes other , < , theerrite , the theidesct the , the thething 9 1 0 , thelysals . the < timeids the unk > , aed to the < < the thenyn ,ult ,irs theosen . the <sts of a < < unk > , . the the beened to unk > , the theashing ,parn the < < a < <mure
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time: 797.20s | valid loss  4.00 | valid ppl    54.75
# -----------------------------------------------------------------------------------------
# | epoch   4 |    50/  332 batches | loss  4.21 | ppl    67.57
# | epoch   4 |   100/  332 batches | loss  4.09 | ppl    59.90
# | epoch   4 |   150/  332 batches | loss  4.07 | ppl    58.79
# | epoch   4 |   200/  332 batches | loss  4.10 | ppl    60.53
# | epoch   4 |   250/  332 batches | loss  4.08 | ppl    59.42
# | epoch   4 |   300/  332 batches | loss  4.07 | ppl    58.37
# =arp ,ain ,a < , =ar < ,ainia < , < as < <an ,rite , < starrite , < a < of the unk > ,rite , the < <antic coastx , < <iassnus , < , < of of the < < , the is aosely <ated to the < <site , theoll <s , the is ben the <ngthus the 0 @ma 1 0 0 1 , the <ive the 0akomeam , . < 9 0 . ) , and then , <istolatedit <id , theosen . the the , the <rite of knownockn and theing the .rite ,uc . theache , theer ofs , the 1mer of thee theithergth . was knownried out the <ale . theper the < , theiraell the the unk > ,vingna thearp ,ainmap , a < @ <imateded byood . and the aidely <atchter . therite .or . andly < the 1 and a of the = =ription = = =ari =ainia < , a <ly unk > of and the < ofngth . to the 0 @imen , ( 1 0 0 ) , thearbo the to the @ 0 0ilomeam , . < 9 0 1 0 ) . ) , and the <rite areambter , ther , ,or , <ually < 0 0 1 0 @ . ) 1 5 2 0 ) the , @ <arbo 0 . @ 5 0 1 0 . @ 5 0ak ) 1 @ . @ 5 0 1 0 . @ 5 6b ) , the the <ashome , , therite are been <mge unk > , was arecllyllge the to thes and the < of < unk > , < unk > ) , the is bes other , < , the birdrite , the theidesct the , the thething 0 1 0 , thelysals . the < timeids the unk > , aed to the < < the the ofyn .ult ,id , theosen . the <sts of a first < unk > of . the the beened by unk > , the theashing .parn the < bird a < <ambure
# -----------------------------------------------------------------------------------------
# | end of epoch   4 | time: 643.64s | valid loss  3.94 | valid ppl    51.44
# -----------------------------------------------------------------------------------------
# | epoch   5 |    50/  332 batches | loss  4.15 | ppl    63.36
# | epoch   5 |   100/  332 batches | loss  4.03 | ppl    56.30
# | epoch   5 |   150/  332 batches | loss  4.02 | ppl    55.55
# | epoch   5 |   200/  332 batches | loss  4.05 | ppl    57.21
# | epoch   5 |   250/  332 batches | loss  4.03 | ppl    56.28
# | epoch   5 |   300/  332 batches | loss  4.01 | ppl    55.35
# =arp ,atheria , , =ar , ,atheria , , < as < <an ,rite , < starrite , < a < of the unk > ,n , , the < regionantic coastxn < <iarsnus , < . < of of the < < . the is aosely <ated to the < populationsite . theoll <s , the is ben the <ngthus the 0 @ma 1 0 0 ) , < <ive the 0akomeam , . < 0 0 . ) , and then , <istectateous <id , theosen . the the . the <r , of knownockn and theing the .rite .uc . theache . theer ofs in the <mer of theing theyga . is <ried out the <ale . theper the < . theira . the the unk > .v .na thear < ,ainsa < , a < @ <imateded byiction . and the aidely <atchter . <r , .or . and of < the same and a of the = =ription = = =arian isiria < , a <ly unk > of and the < ofngthus to the 0 @imen . ( 1 0 0 ) , <arbo the to the @ 1 0ilomeam , . < 0 0 1 0 ) . ) , and the <r of ofambter , ther , ,or . <ually < 0 0 1 0 @m ( 1 @ 2 0 ° 1 , @ <arbo 0 . @ 5 0 1 0 . @ 5 0g ) 1 @ . @ 5 0 1 ° . @ 5 6b ) , the the birdashome of , ther , are been <mge unk > < is arecl bellge the to thes and the < of < unk > , < unk > ) , the is bes bird , < , the birdr , , and theidesct the the the thething 0 1 0 , thestsals . the < timeid of the unk > , aed to the < < the the ofyn .k andir , theosen . the <sts of a < < unk > of . and the beened to unk > , to theashing .par . the < bird a < <ambure
# -----------------------------------------------------------------------------------------
# | end of epoch   5 | time: 678.61s | valid loss  3.90 | valid ppl    49.18
# -----------------------------------------------------------------------------------------
# | epoch   6 |    50/  332 batches | loss  4.10 | ppl    60.31
# | epoch   6 |   100/  332 batches | loss  3.98 | ppl    53.65
# | epoch   6 |   150/  332 batches | loss  3.97 | ppl    53.06
# | epoch   6 |   200/  332 batches | loss  4.00 | ppl    54.75
# | epoch   6 |   250/  332 batches | loss  3.99 | ppl    53.88
# | epoch   6 |   300/  332 batches | loss  3.97 | ppl    53.12
# =ar , ,athersa , , =ar , ,atheria , , < as < <an <r , , < starg , , < a < of the unk > ,n , , the < islandantic oxnia theiarsnus , < . < of of the < < . the is aosely <ated to the < <s , . theoll <s , the is ben the <ngthus the 0 @m ( 1 0 0 ) , < <ive the 0akomeam , . < 0 0b ) , < then the <istuteipous <ir , theosen . the the , the <r , of knownockn and theing the <r , .uc . theache . theer ,s in the 1mer of theing theyga , is <ried out the <ale . theper 1 < . theira . . the unk > .v .na thear < isainsa < , a < @ <imateded byood . and the aidely <ambter . <r , .or . and of < the < and a of the = =ription = = =ar < =irma < , a <st unk > of the the < ofngthus to the 0 @imenres ( 1 0 0 ) , <arbo the to 1 0 1 @ilomeam , . < 0 0 1 0 ) . ) , and the <r of ofambter , ther , ,or , <ually < 0 0 1 @ @m ( 1 @ 1 0 ) 1 ,er <arbo 0 . @ 5 0 1 0 . @ 5 0g ( 1 @ . @ 5 m 1 @ . @ 5 6b ) , the the birdashome of , ther , are been <dle unk > < is havecl bellge the to the , and the < of < unk > < < unk > ) , the is have in bird , < , the birds , , the theidescts the the thething 0 1 @ , thestsals . the < timeid of the unk > , aed to the < < the the ofyn .k <ir , theosen . the <sts of a < < unk > of . and the beened to unk > , to theashing .par . the < < a < <ambure
# -----------------------------------------------------------------------------------------
# | end of epoch   6 | time: 526.70s | valid loss  3.86 | valid ppl    47.57
# -----------------------------------------------------------------------------------------
# | epoch   7 |    50/  332 batches | loss  4.06 | ppl    57.97
# | epoch   7 |   100/  332 batches | loss  3.94 | ppl    51.61
# | epoch   7 |   150/  332 batches | loss  3.94 | ppl    51.17
# | epoch   7 |   200/  332 batches | loss  3.97 | ppl    52.90
# | epoch   7 |   250/  332 batches | loss  3.95 | ppl    52.04
# | epoch   7 |   300/  332 batches | loss  3.94 | ppl    51.32
# =ar , ,athersa and , =arm ,ainedia , , < as < <an <g , , < starg , , the a < of the unk > ,r , , the < bantic oxnia theiarsnus , , . the of of the < < . the is aosely inated to the < <g , , theoll < < , the is ben the <ngthus the 0 @m ( 1 0 0 ) , < < of the 0ilomeam ( . 1 0 0 . ) , < then the <istuteipous <ir , theosen . the the , the <r , of knownockn and theing the .r , ,uc . theache . theer ,s in the 1m of theing theyna , is commonried out the <ale . theper 1 < . theira . . the unk > .ry .na thear < isainmy < , a < @ <imateded byood . and the aidely toitedter . <r , .ten . and of the the < and a of the = =ription = = =arus isainma < , a < @ unk > of the the < ofngthus to the 0 @imenres ( 1 0 0 ) , <arbo the to 1 0 1 @ilomeam , . < 0 @ 1 0 0 . ) , and the <rter ofambter have ther , ,ten , <ually < 0 0 2 0 @m ( 1 0 1 0 km ) , @ <arbo 0 . @ 5 0 1 @ . @ 5 0gu 1 @ . @ 5 k 1 @ . @ 5 6b ) , the the birdashranion ther , are been <dle unk > < is aret toll to the to the to and the < of < unk > . < unk > ) , the is have in bird , < , the birdr , , the theidescts the the thething 0 1 @ , thestsals . the < timeir of the unk > , aed to the < < the a ofissionnick <ir , theosen . the <sts of a < < unk > of . the the beened to unk > , to theashing .par . the < bird a same <ambure
# -----------------------------------------------------------------------------------------
# | end of epoch   7 | time: 519.95s | valid loss  3.83 | valid ppl    46.23
# -----------------------------------------------------------------------------------------
# | epoch   8 |    50/  332 batches | loss  4.03 | ppl    56.07
# | epoch   8 |   100/  332 batches | loss  3.91 | ppl    50.03
# | epoch   8 |   150/  332 batches | loss  3.90 | ppl    49.63
# | epoch   8 |   200/  332 batches | loss  3.94 | ppl    51.38
# | epoch   8 |   250/  332 batches | loss  3.92 | ppl    50.58
# | epoch   8 |   300/  332 batches | loss  3.91 | ppl    49.84
# =aries ,athericyies , =arm ,ainedia and , < as < <an <g , , < starg , , the a common of the unk > ,r , , the < regionantic oxnia theiarsnus ,ia . the of of the < < . the is aosely inative to the < <r , , theoll < < < the is ben the <ngthus the 0 @ma 1 0 0 ) , the < of the 0akomeam ( . 1 0 0b ) , the then the <ervuteipous <ir , theosen . the the , the <r , of knownockn and theing the .r , ,uc . theache . theer ,s in the 1m of theing theynun , is commonried out the <ale . theper 1 < . theiraan . the unk > .ry .na thear < isainmy < , a < @ <imateded byood . and the aidely toitedter . ther , .ten . and of the the < and a of the = =ription = = =arus isainmaus , a < @ unk > of the the < ofngthus to the 0 @imenres ( 1 @ 0 ) , <arbo the to 1 0 1 @ilomeam , . < @ @ 1 0 0 . ) , and the <rter ofambtertle ther , ,ten , <ually < 0 0 1 0 .m ( 1 @ 1 0 km ) , @ <arbo 0 . @ 5 0 1 @ . @ 5 0gu 1 @ . @ 5 k 1 @ . @ 5 6b ) , the the <ashramention therter are been <down unk > , is aret toll to the to the , and the < of < unk > . < unk > ) , the is have in bird , < , the birdr , , the theidesaseds , the thething 0 1 @ , the <sals . the < timeir of the unk > , aed to the < < the a ofanick andir , theosen . the <sts of a < < unk > of . the the beened by unk > , to theashing .par . the < bird a most <ambure
# -----------------------------------------------------------------------------------------
# | end of epoch   8 | time: 742.94s | valid loss  3.81 | valid ppl    45.22
# -----------------------------------------------------------------------------------------
# | epoch   9 |    50/  332 batches | loss  4.00 | ppl    54.57
# | epoch   9 |   100/  332 batches | loss  3.89 | ppl    48.70
# | epoch   9 |   150/  332 batches | loss  3.88 | ppl    48.29
# | epoch   9 |   200/  332 batches | loss  3.91 | ppl    49.99
# | epoch   9 |   250/  332 batches | loss  3.90 | ppl    49.21
# | epoch   9 |   300/  332 batches | loss  3.88 | ppl    48.62
# =arpbillsyies , =arp ,ainedsyies , < as a <an <g , , < starg , , the a common of the unk > ,r , , the < regionantic oxnia theiarsne ,ia . the of of the < < . the is aosely inative to the < <gter , theoll < < < the is ben the <ngthus the 0 @ma 1 0 ° ) , the < of the 0ilomeam ( . 1 @ 0b ) , the then a <ervuteipous <ir , theosen . the the , the <rter are knownockn and theing the .rter ,uc . theache . theer ,s in the <m of theing theygle , is commonried out the <ale . theper 1 < . theiraine . the unk > .ryanna thear < isainmy < is a < @ <imateded byood . and the aidely .ambter . ther , .et . and of to the < and a of the = =ription = = =arus isillmyus is a < @ unk > of the the < ofngthusper the 0 @imenres ( 1 @ @ ) , thearbo the to 1 0 1 @ilomeam ( . < @ @ 1 0 )b ) , and the <rter areambter , ther , ,und , <ually < 0 0 1 0 .m ( 1 @ 1 0 ) ) , @ <arbo 0 . @ 5 0 1 @ . @ 5 0gg 1 @ . @ 5 k 1 @ . @ 5 6b ) , the the <ashramention therter are been <down unk > , is aret toarge the to the , and the < of < unk > . < unk > ) , the is be in times , < of the birdr , , the theidesaseds , the thething 0 1 @ , the <sals . the < timeir of the unk > , aed to the < < the a ofanick andir , theosen . the <sts of a < < unk > of . the the beened by unk > . in theashing .par . the < bird a < <amby
# -----------------------------------------------------------------------------------------
# | end of epoch   9 | time: 681.88s | valid loss  3.79 | valid ppl    44.29
# -----------------------------------------------------------------------------------------
# | epoch  10 |    50/  332 batches | loss  3.97 | ppl    53.17
# | epoch  10 |   100/  332 batches | loss  3.86 | ppl    47.58
# | epoch  10 |   150/  332 batches | loss  3.85 | ppl    47.20
# | epoch  10 |   200/  332 batches | loss  3.89 | ppl    48.87
# | epoch  10 |   250/  332 batches | loss  3.87 | ppl    48.09
# | epoch  10 |   300/  332 batches | loss  3.86 | ppl    47.69
# =argetbillsyies , =arm ,illsyia , and as a <an <g , ,b starg , , the a common of the unk > ,g , , the < regionantic oxnia theiarsnus ,ia . thes of the < < . the is aosely inative to the < <gter of whichun < < < the is ben the <ngthus the 0 @ma 1 0 ° ) , the < of the 0ilomeam ( . 1 0 0b ) , the then a <ervuteipouslyir of theosen . the the , the <rter are knownockn and theing the .rter ,uc . theache . theer ,s in the <m of theing theygle , is theried out the <ale . theper 1 < . theiraine . the unk > .ryanna thear < isainsym , a < @ <imateded byood . and the aidely inambter . therter .ten . and of the the < andol of the = =ription = = =arus isillsaries is a < @ unk > of the the < ofavegthusper the 0 @imenres ( 1 @ 0 ) , thearbo the to 1 0 1 @ilomeam , . 1 @ @ 1 0 )b ) , and the <rter areambter the therter ,und , <ually < 0 0 1 0 .m ( 1 @ 1 0 ) ) , @ <arbo 0 . @ 5 0 1 @ , @ 5 0gg 1 @ . @ 5 k 1 @ . @ 5 6b ) , the the <ashracraftion therter are been <down unk > , is aret toarge the to the , and the < of < unk > . < unk > ) , the is be in bird , < of the birdg , ( the theidesaseds , the thething 0 1 0 , the <sals . the < timeir of the unk > , aed to the < < the a ofanick andir , theosen . the <sts of a < < unk > of . the the beened by unk > . in theashing .par . the < bird a < <amby
# -----------------------------------------------------------------------------------------
# | end of epoch  10 | time: 632.19s | valid loss  3.77 | valid ppl    43.57
# -----------------------------------------------------------------------------------------
# | epoch  11 |    50/  332 batches | loss  3.95 | ppl    52.04
# | epoch  11 |   100/  332 batches | loss  3.84 | ppl    46.60
# | epoch  11 |   150/  332 batches | loss  3.83 | ppl    46.25
# | epoch  11 |   200/  332 batches | loss  3.87 | ppl    47.86
# | epoch  11 |   250/  332 batches | loss  3.85 | ppl    47.19
# | epoch  11 |   300/  332 batches | loss  3.84 | ppl    46.61
# =arget ,illsaia , =arm ,illinaia , and as a <an <g , ,b starg , , the a < of the unk > ,g , , the < regionantic oxnia whichiarsnun ,ia . <s of the < < . the is aosely inative to the < populationgter of whichun < < , the is ben the <ngthus the 0 @m ( 1 0 ° ) , the < of < 0akomeam , . 1 9 @b ) , which then a <ervassipouslyir of theosen . the the , the <rter are knownockn and theing the .rter ,uc . theache . theer ,s in the <m of theing theggle , is theried out the <ale . theper 1 < . theira and . the unk > .ryanna theari isillmarm , a < @ <imatedated byood . and the aildly ineleter . therter .et . and of the the < andl of the = =ription = = =ari isillmyi is a < @ unk > of the the < ofavegthusper the 0 @imenres ( 1 @ @ ) , <arbo to to 1 0 1 @ilomeam , . < 0 @ 1 0 )b ) , and the <rter areambter the therter ,und , <ually < 0 @ 1 @ .m ( 1 @ 1 0 – ) , @ <arbo 0 . @ 5 0 1 @ , @ 5 kgg 1 @ . @ 5 k 1 @ . @ 5 0b ) , the the birdashraaion therter are been <bole unk > , is aret toarge the to the , and the < of < unk > . < unk > ) , the is be in bird , < of the birdrter ( the theidesaseds , the thething 0 1 @ , the <sals . the k timeir of the unk > , aed to the < < the a ofalnick andirs theosea . the <sts of a < < unk > of . the the beened by unk > . in theashing .par . the < bird a < <amby
# -----------------------------------------------------------------------------------------
# | end of epoch  11 | time: 621.63s | valid loss  3.76 | valid ppl    43.01
# -----------------------------------------------------------------------------------------
# | epoch  12 |    50/  332 batches | loss  3.93 | ppl    51.03
# | epoch  12 |   100/  332 batches | loss  3.82 | ppl    45.70
# | epoch  12 |   150/  332 batches | loss  3.82 | ppl    45.39
# | epoch  12 |   200/  332 batches | loss  3.85 | ppl    47.09
# | epoch  12 |   250/  332 batches | loss  3.83 | ppl    46.18
# | epoch  12 |   300/  332 batches | loss  3.82 | ppl    45.73
# =arp ,illsa and , =arc ,illinaia , and aster <an <g , ,b starg , , the a < of the unk > ,gter , the < regionantic ocenia whichiarsne ,ia . <s of the < < . the is aosest inative to the < <gter of whichun < < , the is ben the <ngthus the 0 @m ( 1 0 0 ) , the < of the 0akomeams . 1 9 0b ) , which then a <ervassipous andir of theosen . the the , the <rter are alsoown and theing a .rter ,uc . theache . theer ,red in the <m of theing theygle , is alsoried out the <ale . theper 1 < . theira and . the unk > .ryanna theari isillmy < is a < @ toimatedated byood . and the aildly inelet . <rter .et . and of to the < andol , the = =ription = = =arus isillmy = is a < @ unk > , the the < ofavegth of to the 0 @resnres ( 1 @ km ) , <arbo in to 1 0 1 0gomeams . 1 9 @ 1 0 )b ) , and the <rter aremter the therter ,und , <ually < 0 @ 1 0 .m ( 1 @ 1 0 – ) , @ <arbo 0 . @ 5 0 1 0 . @ 5 kgg 1 @ . @ 5 k 1 @ . @ 5 inb ) , the the birdash ,a , therter are been <bod unk > , is aret toarge the to the . and the < of < unk > . < unk > ) , the is be in bird , < , the birdrter ( and theidesaseds , the thething 0 1 0 , the <sals , the bird timeir of the unk > , aed to the < < the a ofalnick andirs theosen . the birdsts of a < < unk > of . the the beened by unk > . . theash . .par . the bird bird a < <atchh
# -----------------------------------------------------------------------------------------
# | end of epoch  12 | time: 629.16s | valid loss  3.75 | valid ppl    42.51
# -----------------------------------------------------------------------------------------
# | epoch  13 |    50/  332 batches | loss  3.91 | ppl    50.09
# | epoch  13 |   100/  332 batches | loss  3.80 | ppl    44.84
# | epoch  13 |   150/  332 batches | loss  3.80 | ppl    44.60
# | epoch  13 |   200/  332 batches | loss  3.83 | ppl    46.20
# | epoch  13 |   250/  332 batches | loss  3.82 | ppl    45.38
# | epoch  13 |   300/  332 batches | loss  3.81 | ppl    44.95
# =arp ,illsa , , =arc ,illinac , and aster <an <gter ,b stargter , the a < of the unk > ,gter . the < regionantic ocenia whichiar ,nun ,ia . <s . the < . , the is aosest inative to the < <rter of whichun < < , the is ben the <ngthus the 0 @m ( 1 0 0 ) , the <ive the @akomeams . 1 9 0b ) , which then a <ervassipous andir of theosen . the the , the <rter are alsoockn and theing a .rter ,uc . theache . theer ,red in the <mer of theing theygle , is <ried out the <ale . theper 1 < . theira and . the unk > .ryanna thearm isillmym is a < @ toimatedated byood , and the aildly inatcht . <rter .et . and of to the < and a , the = =ription = = =arus isirmy = is a < @ unk > of the the < ofavegth of to the 0 @imetres ( 1 @ @ ) , <arbo to to 1 0 1 0ilomeams . 1 9 @ 1 0 )b ) , and the <rter aremter in therter ,et , <ually < 0 @ 1 @ .m ( 1 @ 1 0 – ) , @ <arbo 0 . @ 5 0 1 @ . @ 5 kgg 1 9 . @ 5 k 1 @ . @ 5 0b ) , the the birdashersaion therter are been <bo @ unk > . is aret bearge the to the , and the < of < unk > . < unk > ) , the is be in bird , < , the birdgter ( the theidesases , the thething 0 1 0 , the <sals , the bird isir of the unk > , aed to a < @ the a ofalnick ,ir , theosea . the birdsts of a < < unk > of . and the beened by unk > . . theashing .m . the < bird a < <atchy
# -----------------------------------------------------------------------------------------
# | end of epoch  13 | time: 610.94s | valid loss  3.74 | valid ppl    42.21
# -----------------------------------------------------------------------------------------
# | epoch  14 |    50/  332 batches | loss  3.90 | ppl    49.20
# | epoch  14 |   100/  332 batches | loss  3.79 | ppl    44.09
# | epoch  14 |   150/  332 batches | loss  3.78 | ppl    43.84
# | epoch  14 |   200/  332 batches | loss  3.82 | ppl    45.49
# | epoch  14 |   250/  332 batches | loss  3.80 | ppl    44.63
# | epoch  14 |   300/  332 batches | loss  3.79 | ppl    44.22
# =arp ,illsy , and =arc ,illiny , , the aster <an ,gter ,b stargter , the a < of the unk > ,gter . the < regionantic ocenia andiar ,nun ,ia . < of of the < . . the is aosest inative to the < <rter of whichun < < < the is ben the <ngthus the 0 @m ( 1 0 0 ) , < < of the @gomeams . 1 9 @b ) , which then a <ervassipouslyir of theosea . the the , the <rter are alsoockn and ining a .rter .uc . theache . theer ,red in the <mer of theing theggs , are alsoried out the <ale . theper 1 < . theira and . the unk > .ryanna thearm isillmarm is a < @ <imatedated byood . which the aidely inatchtain <rter .et . and of of the < and a of the = =ription = = =arus isillmy = is a < @ unk > of the the < ofavegth of to 1 0 @imetres ( 1 @ @ ) , <arbo . to 1 0 1 0gomeams . < 9 @ 1 0 )b ) , which the <rter areatchterain therter ,et , <ually , 0 @ 1 @ .m ( 1 @ 1 0 – ) , @ <arbo 0 . @ 5 in 1 @ . @ 5 kgg 1 9 . @ 5 k 1 @ . @ 5 inb ) , the < birdashersa , therter are been <bo @ unk > . is aret bearge the to the , and the < . < unk > . < unk > ) , the is be in bird , < , the birdgter ( the theidesases , the thething 0 1 0 , the ,sals . the bird isir of the unk > , aed to a < < andter ofalnick ,ir , theosea . the birdsts of a first < unk > of . the the beened by unk > . . theash . .m . the bird bird a < <atch ,
# -----------------------------------------------------------------------------------------
# | end of epoch  14 | time: 615.88s | valid loss  3.74 | valid ppl    41.98
# -----------------------------------------------------------------------------------------
# | epoch  15 |    50/  332 batches | loss  3.88 | ppl    48.54
# | epoch  15 |   100/  332 batches | loss  3.77 | ppl    43.42
# | epoch  15 |   150/  332 batches | loss  3.77 | ppl    43.21
# | epoch  15 |   200/  332 batches | loss  3.80 | ppl    44.84
# | epoch  15 |   250/  332 batches | loss  3.78 | ppl    43.96
# | epoch  15 |   300/  332 batches | loss  3.78 | ppl    43.60
# =arp ,illsy , and =arc ,iriny , , the aster <an ,rter , < starrter , the a < of the unk > ,rter . the < regionantic oxania andiar ,nun ,a . < of . the < . . the is aosest inative to the < <rter of whichun < < < the is ben the <ngth of the 0 @ma 1 0 0 ) , the < of the @gomeams . 1 9 @b ) , and then a <ervassipouslyir of theosea . the the , the <rter are alsoockn and theing a .rter ,uc . theache . theer ,red in the <mer of theing theggs , are commonried to the <ale . theper 1 < . theira and . the unk > .ryanna thearc isillinar is is a < @ <imatedated byood . and the aidely inatchtain therter .or . andly of the < and a of the = =ription = = =arus isilliny is is a < < unk > of the a < ofavegth of to 1 0 @imetres ( 1 @ @ ) . <arbo that to 1 @ 1 0gomeams . < 9 @ 1 0 )b ) . and the <rter areatchterain therter ,or , <ually , 0 @ 1 @ .m ( 1 @ 1 0 – ) . @ <ightbo 0 , @ 5 in 1 @ . @ 5 ingg 1 9 . @ 5 m 1 @ . @ 5 inb ) , the the birdashersa , therter are been <bod unk > . is aret .arge the to the , and the < . < unk > . < unk > ) . the is be in bird , < of the birdgter ( and theidesases are the thething 0 1 0 , the < .als . the bird timeir of the unk > ( aed to a < < andterondalnick <ir , theosea . the birdsts of a first < unk > of . and the beened by unk > . . theash . .par . the bird bird a < <atchs
# -----------------------------------------------------------------------------------------
# | end of epoch  15 | time: 712.02s | valid loss  3.73 | valid ppl    41.53
# -----------------------------------------------------------------------------------------
# | epoch  16 |    50/  332 batches | loss  3.87 | ppl    47.82
# | epoch  16 |   100/  332 batches | loss  3.76 | ppl    42.79
# | epoch  16 |   150/  332 batches | loss  3.75 | ppl    42.62
# | epoch  16 |   200/  332 batches | loss  3.79 | ppl    44.26
# | epoch  16 |   250/  332 batches | loss  3.77 | ppl    43.36
# | epoch  16 |   300/  332 batches | loss  3.76 | ppl    42.96
# =arp ,illsa , , =arc ,illsa , , the as the <an ofr , , < starr , , and a < of the unk > ,rter . the < regionantic oxania andiar ,nun ,a . < of . the < . . the is aosely inative to the < <rter of whichun < <ia the is ben the <ngth of the 0 @ma 1 0 ° ) , the < of the @gomeams . 1 9 @b ) , and then a <ervassipouslyid of theosea . the the , the <rter are alsoockn and theing a .rter ,uc . theache . theer ,s in the <mer of theing theggs , are commonried to the birdale . theper 1 < . theira and . the unk > .ryanna thearc isillinar is is a < @ <imatedatic byood . and the aidely inatchtain therter .or . andly of the < andol of the = =ription = = =arus isillinar is is a < < unk > of the the < ofavegth ofper the 0 @imetres ( 1 @ @ ) . thearbo that to 1 0 1 0gomeams . < 9 0 1 0 )b ) . and the <rter areatchterain therter ,or , <ually , 0 @ 1 @ .m ( 1 @ 1 0 – ) . . <ightbo 0 , @ 5 in 1 @ . @ 5 ingg 1 9 . @ 5 m 5 @ . @ 5 inb ) , the the birdashersa , therter are been <dd unk > . is aret bellota the to the , and the < . the unk > . < unk > ) . the is be in bird , < , the birdrter , and theidesases are the theone 0 1 0 , the < .als . the bird isir of the unk > , aed to a < < andterondalnicus <ir , theosea . the birdst , of a first < unk > of . and the beened by unk > . . theash . .y . the bird bird a < <atchs
# -----------------------------------------------------------------------------------------
# | end of epoch  16 | time: 515.99s | valid loss  3.72 | valid ppl    41.12
# -----------------------------------------------------------------------------------------
# | epoch  17 |    50/  332 batches | loss  3.85 | ppl    47.15
# | epoch  17 |   100/  332 batches | loss  3.74 | ppl    42.17
# | epoch  17 |   150/  332 batches | loss  3.74 | ppl    42.08
# | epoch  17 |   200/  332 batches | loss  3.78 | ppl    43.60
# | epoch  17 |   250/  332 batches | loss  3.75 | ppl    42.72
# | epoch  17 |   300/  332 batches | loss  3.75 | ppl    42.38
# =arp ,illsa , , =arc ,irsa , , < as < <an ofr , , < starr , , and a < of the unk > ,rter . the < regionantic oxania andiar ,n < ,a . < of . the < . . the is aosely ,ative to the < <rter , whichun < <ia the is ben the <ngthus the 0 @ma 1 0 km ) . the <ive the @ilomeams . 1 9 0b ) . and then a <ervassipous speciesid of theosea . the the , the <rter are alsoockn and theing a .rter ,uc . theache . theer ,red in the <mer of theing theygs , are commonried out the birdale . theper 1 < . theira . . the unk > .ryanna thearc isarinar is is a < @ ofimatedatic byood . and the aidely inatchtain therter .or . andly of the bird andol of the = =ription = = =arus isarinar is is a < < unk > of the the < ofavegth ofper the 0 @imetres ( 1 @ km ) . thear and that to 1 @ 1 0gomeams . < 9 0 1 0 )b ) . and the <rter areatchterain therter ,or , <ually , 0 @ 1 @ .m ( 1 @ 1 0 ) ) . . <ightbo 0 , @ 5 in 1 @ . @ 5 ing ( 1 9 . @ 5 m 3 @ . @ 5 inb ) , the the birdashersa is therter are been <dd unk > . is aret bellota the to the , and the < . < unk > . < unk > ) . the is be in bird , < , the birdrter . and theidesase the are the theone 0 1 0 , the < .als . the bird isir of the unk > , aed in the < < andteronalnicus <ir , theosea . the birdst , of a first < unk > of . and the beened by unk > . . theash . .y . the bird bird a most <atchs
# -----------------------------------------------------------------------------------------
# | end of epoch  17 | time: 622.54s | valid loss  3.71 | valid ppl    40.78
# -----------------------------------------------------------------------------------------
# | epoch  18 |    50/  332 batches | loss  3.84 | ppl    46.48
# | epoch  18 |   100/  332 batches | loss  3.73 | ppl    41.59
# | epoch  18 |   150/  332 batches | loss  3.73 | ppl    41.57
# | epoch  18 |   200/  332 batches | loss  3.76 | ppl    43.14
# | epoch  18 |   250/  332 batches | loss  3.74 | ppl    42.19
# | epoch  18 |   300/  332 batches | loss  3.73 | ppl    41.87
# =arp ,illsa , , =arc ,irsa , , < aster <an ofr , , < starr , , and a < of the unk > ,rite . the < <antic oceania andiar ,n < ,a . < of . the < @ . the is aosely ,ative to the < <rter . whichun < <ia the is ben the <avegthus the 0 @ma 1 0 km ) . the <ive the @ilomeams . 1 9 0b ) . and then a <ervassateous speciesir , theosea . the the , the <rter are alsouen and theing a .rter ,uc . theache . theer ,red in the <mer of theing theygs , are <ol out the kale . theper 1 < . theiran . . the unk > .ryanna thearp isarmar is is a < @ ofimatedatic byood . and the aidely toatchtain therter .or . andly of the bird andol . the = =ription = = =arus isariar is is a < < unk > of the the < ofavegthus to the @ @restres ( 1 @ – ) . thear and to to 1 @ 1 0gomeam . . < 9 0 1 0 )b ) . and the <rter areatchter the therter ,or , <ually < 0 @ 1 @ .m ( 1 @ 1 0 ) ) . . <ightbo @ , @ 5 in 1 @ . @ 5 kg ( 1 9 . @ 5 m 3 @ . @ 5 inb ) , the the birdashers is , therter are been <dd unk > . is aret bellota the to the , and the < . < unk > . < unk > ) . the is be in bird , < , the birdrter . and theidesase the are the theone 0 1 0 , the < .als . the bird isir of the unk > , aed . the < < andteronalnicus <ir , theoseay . the birdst , of a first < unk > of . and the beened to unk > . . theash . .y . the bird bird a most <atchs
# -----------------------------------------------------------------------------------------
# | end of epoch  18 | time: 576.89s | valid loss  3.70 | valid ppl    40.60
# -----------------------------------------------------------------------------------------
# | epoch  19 |    50/  332 batches | loss  3.83 | ppl    46.01
# | epoch  19 |   100/  332 batches | loss  3.72 | ppl    41.09
# | epoch  19 |   150/  332 batches | loss  3.72 | ppl    41.06
# | epoch  19 |   200/  332 batches | loss  3.75 | ppl    42.60
# | epoch  19 |   250/  332 batches | loss  3.73 | ppl    41.65
# | epoch  19 |   300/  332 batches | loss  3.72 | ppl    41.43
# =arpesainedsa , , =arc ,irsa , , < as < <an ofr , , < starr , , and a < of the unk > ,rite . the < <antic oxania andiarran < ,a . < of . the < @ . the is aosedly ,ative to the < <rter . whichun < < , the is ben the <avegthus the @ @m ( 1 0 km ) . the <ive the @ilomeams . 1 9 5b ) . and thenon <ervuteateous speciesir , theosea . the the , the <rter are alsoockn and theing a .rter ,uc . theache . theer ,red in the <m of anding theygs , is <ried out the kale . theper 1 < . theiran . . the unk > .ry .na thearp isarmar is is a < @ toimatedatic byood . and the aidely toatcht the therter .or . andly of the < andol . the = =ription = = =arus isarmar is is a < < unk > , the the < ofavegth of to the @ @restres ( 1 @ – ) . thear and to to 1 @ 1 @gomeam . . < 9 0 1 0 )b ) . and the <rter areatchter the therter ,or , <ually < 0 @ 1 @ .m ( 1 @ 1 0 ) ) . . <ight and @ , @ 5 in 1 @ . @ 5 kg ( 1 9 . @ 5 m 3 @ . @ 5 inb ) , the the birdashers is , therter are been <dd unk > , is aret bellota the to the , and the < . < unk > . < unk > ) . the is be in bird , < , the birdr . , and theidesase the are the theone 0 1 0 , the < .als . the bird isir of the unk > , aed . the < < andteronalnical <ir , theosea . the <st , of a first < unk > of . and the beened to unk > . . theash . .y . the bird bird a < <atchs
# -----------------------------------------------------------------------------------------
# | end of epoch  19 | time: 668.67s | valid loss  3.70 | valid ppl    40.36
# -----------------------------------------------------------------------------------------
# | epoch  20 |    50/  332 batches | loss  3.82 | ppl    45.77
# | epoch  20 |   100/  332 batches | loss  3.71 | ppl    40.73
# | epoch  20 |   150/  332 batches | loss  3.70 | ppl    40.65
# | epoch  20 |   200/  332 batches | loss  3.74 | ppl    42.16
# | epoch  20 |   250/  332 batches | loss  3.72 | ppl    41.15
# | epoch  20 |   300/  332 batches | loss  3.71 | ppl    40.95
# =arp ,ainedsa , , =arp ,irsa , , < as < <an ofr , , < starr . . and a < of the unk > ,rite . the < <antic oxania andiarran < ,a . < of . the < @ . the is aosedly ,ative to the < <rter . andun < <ia the is be , the <ngthus the @ @m ( 1 0 km ) . the <ive the @ilomeams . 1 9 0b ) . and thenon <ervectateous speciesid , theosea . the the , the <rter are <ockn and theing to .rter ,uc . theache . theer ,s in the <mer of anding <ygs , are <ried out the kale . theper 1 < . theiran . . the unk > .v .na thearp isarmar , is a < @ toimatedatic byood . and the aidely toatcht the therite .or . andly of the < andol . the = =ription = = =arus isarmar is is a < < unk > , and the < ofngth of to the @ @restres ( 1 @ @ ) . thear and . to 1 @ 1 @gomeams . < 9 0 1 0 )b ) . and the <rter areatchter the therter ,or , <ually < @ @ 1 @ .m ( 1 @ 1 0 ) ) . . <ak and @ , @ 5 in 1 @ . @ 5 kg ( 1 9 . @ 5 m 1 @ . @ 5 inb ) , the the birdashers is , therter are been <bod unk > , is aret bellen the to the , and the < . < unk > . < unk > ) . the is be in other , < , the birdr . , and theidesase the are be theone 0 1 0 , the < .als . the bird isir of the unk > , aed . the < < andteronalnical <ir , theosea . the birdst , of a same < unk > , . and the beened to unk > . . theash . .y . the bird bird a same <ut @
# -----------------------------------------------------------------------------------------
# | end of epoch  20 | time: 547.72s | valid loss  3.69 | valid ppl    40.12
# -----------------------------------------------------------------------------------------
# | epoch  21 |    50/  332 batches | loss  3.81 | ppl    45.07
# | epoch  21 |   100/  332 batches | loss  3.69 | ppl    40.22
# | epoch  21 |   150/  332 batches | loss  3.69 | ppl    40.20
# | epoch  21 |   200/  332 batches | loss  3.73 | ppl    41.70
# | epoch  21 |   250/  332 batches | loss  3.71 | ppl    40.68
# | epoch  21 |   300/  332 batches | loss  3.70 | ppl    40.53
# =arp ,ainedsa , , =arp ,irsa , , < aster <an ofrter , < starr . . and a < of the unk > ,rite . the < <antic oxania andiarran , ,a , < of . the < @ . the is aosedly inative to the < <rite . andun < <ia the is ben the <ngthus the @ @mm 1 0 km ) . the <ive the @akomeams . 1 9 0b ) . and thenon <ervirateidlyid , theima . the the , the <rter are <ockn and theing to .rter ,uc . theache . theer ,s in the <mer of anding ofygs , are <ried out the <ale . theper 1 < . theiran . . the unk > .v .na thearp isarmar , is a < @ toimatedated inood . and the aidely <elet in <rite .or . andly of the < andol . the = =ription = = =arus isarmar , is a < < unk > , the the < ofngth of to the @ @urtres ( 1 @ @ ) . theak and . to 1 @ 1 @gomeams . < 9 0 1 0 )b ) . and the <rter areambter in therter ,or , <ually < @ @ 1 @ .m ( 1 @ 1 0 ) ) . . <bs and @ . @ 5 in 1 @ . @ 5 ing ( 1 9 . @ 5 m 1 @ . @ 5 inb ) , the the birdashers is , therter are been <bod unk > , is aret bellen the to be , and the < of < unk > . < unk > ) . the is be in other , < , the birdr . , and theidesase the are be .one 0 1 0 , the < .als . the bird isir of the unk > , aed . the < < andteronalnicus <ir , theoses . the birdst , of a same < unk > , . and the beened to unk > . . theash . .y . the bird bird a same <eleing
# -----------------------------------------------------------------------------------------
# | end of epoch  21 | time: 612.28s | valid loss  3.69 | valid ppl    39.89
# -----------------------------------------------------------------------------------------
# | epoch  22 |    50/  332 batches | loss  3.80 | ppl    44.53
# | epoch  22 |   100/  332 batches | loss  3.68 | ppl    39.78
# | epoch  22 |   150/  332 batches | loss  3.68 | ppl    39.80
# | epoch  22 |   200/  332 batches | loss  3.72 | ppl    41.32
# | epoch  22 |   250/  332 batches | loss  3.70 | ppl    40.25
# | epoch  22 |   300/  332 batches | loss  3.69 | ppl    40.14
# =arp ,ainsa , , =ar , ,assa , , < aster <an ofrter , < starrite . and a < of the unk > ,rite . the < <antic oxania andiarran , ,ar < of . the < @r the is aosely inative to the < <rite . andun < <ia the is ben the <avegthus the @ @m ( 1 0 km ) . the <ive the @ilomeams . 1 9 0b ) . and thenon <ervirateous speciesid , theimay . the the , the <rter are <ockn and theing to .rite ,uc . theache . theer ,s in the <mer of anding ofygs , are <ried out the <ale .wardper 1 < . theiran . . the unk > .vanna thearp isarmar , is a < @ <imatedated inood in and the aidely <elet in <rite .ten . andly of the < <ol . the = =ription = = =ar < isarmar , is a < < unk > , the the < ofngth of to the @ @urtres ( 1 @ @ ) . <ar and . to 1 @ 1 @gomeams . < 9 0 1 0 )b ) . and the <rter areambter in therter ,or , <ually < @ @ 1 @ .m ( 1 @ 1 0 ) ) . . <bsed @ . @ 5 in 1 @ . @ 5 ing ( 1 9 . @ 5 km 1 @ . @ 5 inb ) , the the birdashers is , therter are been <bod unk > , is aret bellen the to be , and the < of < unk > . < unk > ) . the is be in times , fem , the birdr . , and theidesase the are be .one 0 1 . , the < .als . the bird isir of the unk > , aed . a < < and amalnicus <ir , theimay . the birdst , of a same < unk > , . and the beened to unk > , . theash . .y . the bird bird a same <eleing
# -----------------------------------------------------------------------------------------
# | end of epoch  22 | time: 615.87s | valid loss  3.68 | valid ppl    39.74
# -----------------------------------------------------------------------------------------
# | epoch  23 |    50/  332 batches | loss  3.79 | ppl    44.09
# | epoch  23 |   100/  332 batches | loss  3.67 | ppl    39.44
# | epoch  23 |   150/  332 batches | loss  3.68 | ppl    39.45
# | epoch  23 |   200/  332 batches | loss  3.71 | ppl    41.00
# | epoch  23 |   250/  332 batches | loss  3.69 | ppl    39.92
# | epoch  23 |   300/  332 batches | loss  3.68 | ppl    39.82
# =arp ,illsac , =arm ,assam , < aster <an ofrite , < starrite . and a < of < unk > <rite . the < <antic oceania andiarran < ,a , < of . the < @r the is aosely inative to the < <rite . andun < <ia the is ben the <ngthus the @ @mm 1 @ km ) . the <ive the @ilomeams . 1 9 5b ) . and thenon <ervirateid speciesid , theimay . the the , the <rter is <ockn and theing to ,rite ,uc . theache . theer ,s in the <mer of anding ofygs , are <ried out the kale .wardper 1 . . theirch . . the unk > .vanna thearm isarmar , is a < @ <imatedated inood in and the aidely <elet in <rite .ten . andly of the < <ol . the = =ription = = =ar < isillmad ( is a < < unk > , the the < ofngthusper the @ @urta ( 1 @ km ) . <aped . to 1 @ 1 @gomeams . < 9 0 1 6 )b ) . and the <rter areambter in therter ,or , <ually < @ @ 1 @ .m ( 1 @ 5 0 ) ) . . <bsed @ . @ 5 in 1 @ . @ 5 ing ( 1 9 . @ 5 m 1 @ . @ 5 inb ) , the the birdashers is , therter are been <bod unk > , is areter bellen the to theing and the < of < unk > . < unk > ) . the is be in times , < , the birdg . ( and theidesase the are be . bird 0 1 0 , the < .als . the bird isir of the unk > , aed . a < < and aonaltical <ir , theimay . the birdst < of a < < unk > , . and < beened in unk > , . theash . .y . the < bird a < <ambing
# -----------------------------------------------------------------------------------------
# | end of epoch  23 | time: 552.53s | valid loss  3.68 | valid ppl    39.71
# -----------------------------------------------------------------------------------------
# | epoch  24 |    50/  332 batches | loss  3.78 | ppl    43.70
# | epoch  24 |   100/  332 batches | loss  3.67 | ppl    39.08
# | epoch  24 |   150/  332 batches | loss  3.67 | ppl    39.13
# | epoch  24 |   200/  332 batches | loss  3.71 | ppl    40.69
# | epoch  24 |   250/  332 batches | loss  3.68 | ppl    39.57
# | epoch  24 |   300/  332 batches | loss  3.68 | ppl    39.46
# =arli ,ainsac , =armusiansaia , < aster <anarter , < starrite . and a < of < unk > <rite . the < <antic oceania andiarrania ,a , <s . the < @r the is aosely inative to the < <rite . andun < <ia the is ben the <ngthus the @ @mm 1 0 km ) . the <ive the @ilomeams . 1 9 5b ) . and thenon <ervirateid speciesir , theimay . the the , the <rter is commonockn and theing to ,rite ,uc . theuge . theer ,s in the birdmer of ande ofggs , is commonried out the kale . theper 1 . . theirch . . the unk > .valna thearm isarmad ( is a < @ <imatedated inood in and the aidely <ambt in <rite .ten . andly of the < <ol . the = =ription = = =ar < isillma ( is a < < unk > , the the < ofngthus to the @ @urta ( 1 @ km ) . <ared . to 1 @ 1 0gomeams . < 9 0 1 9 )b ) . and the <rter areambter in therter ,or , <ually < @ @ 5 @ .m ( 1 @ 5 0 ) ) . . <bsed @ . @ 5 in 1 @ . @ 5 ing ( 1 9 . @ 5 k 1 @ . @ 5 inb ) , the the birdashers is , therter are been <dd unk > , is areter bellen the to theing and the < of < unk > . < unk > ) . the is be in bird , < , the birdg . ( and theidesase the are the inone 0 1 0 , thely .als . the bird isir of the unk > , aed . a < < and aonalticus <ir , theims . the <st < of a < < unk > < . and < beened in unk > , . theash . .y . the < bird a < <ambing
# -----------------------------------------------------------------------------------------
# | end of epoch  24 | time: 594.39s | valid loss  3.68 | valid ppl    39.49
# -----------------------------------------------------------------------------------------
# | epoch  25 |    50/  332 batches | loss  3.77 | ppl    43.37
# | epoch  25 |   100/  332 batches | loss  3.66 | ppl    38.78
# | epoch  25 |   150/  332 batches | loss  3.66 | ppl    38.87
# | epoch  25 |   200/  332 batches | loss  3.70 | ppl    40.34
# | epoch  25 |   250/  332 batches | loss  3.67 | ppl    39.28
# | epoch  25 |   300/  332 batches | loss  3.67 | ppl    39.15
# =arliesillsac , =armusianiaia , < ast <an <rtera < starrite , < a < of < unk > <ritea the < <antic ocean , <iarrania ,a , <s . the < @ , the is aose to inative to the < <rite , andun < <et the is ben the <ngthus the 0 @m ( 1 @ km ) . the <ive the @ilomeams . 1 9 5b ) . and thenon <ervirateous speciesirs theima . the the , the <rter is commonockled and theing a <rite ,uc . theuge . theer ,s in the birdmer of anding <ygs , are commonried out the kale .estper 1 < . theiran . . the unk > .valna thearus isarmar ( is a < @ <imatedated inood in and < aidely <elet in <rite .ten . andly of the < <ol . the = =ription = = =arus isillma ( is a < < unk > , the the < ofngthus to the @ @urta ( 1 @ km ) . <bsed . to 1 @ 1 0gomeams . < 9 0 1 9 )b ) . and the <rter areambter in therter ,ten , <ually < @ @ 5 @ .m ( 1 @ 5 0 ) ) . . 1bsed @ , @ 5 in 1 @ . @ 5 ing ( 1 9 . @ 5 m 1 @ . @ 5 inb ) , the the birdashers is , therter are been <dd unk > , is areter bellen the to being and the . of < unk > . < unk > ) . the is be in bird , < , the birdg . ( and theidesase the are the in bird 0 1 @ , the , .als . the bird isir of the unk > , aed to a < < and aonaltical ,ir , theims . the <st < of a < < unk > < . and < beened by unk > , to theash . .y . the < bird a < <eleure
# -----------------------------------------------------------------------------------------
# | end of epoch  25 | time: 526.08s | valid loss  3.67 | valid ppl    39.38
# -----------------------------------------------------------------------------------------
# | epoch  26 |    50/  332 batches | loss  3.76 | ppl    43.12
# ...
# =ar , ,ainedsa ,z =arpa .sahca the as the <an ofgiteed < starg ofed the the < of < unk > ,seite , the < <antic coastcen , theiterraneus < in <s of the < @ . the is aosed to <ative to the <srter , andind < < , the is have in the <ngth of the 0 0 . ( 1 0 km ) , the < of the 0ilomeams . < @ 0b ) . and then a <istiruitlyir of theims . the the , the <rter are commonockn the oneing a ,rite ,uc , theaching , theerines in the <mer of theing <ygs , are commonry out the <ale . the to 1 < , theirland . , the unk > .vans thearin ,illsar , , a <est <imatedatic inood in the the aidely <atcht in thegter .ten . andly the the < <ol . the = =ription = = thearm isills ( , is a <ly unk > , the the < ofavegth of to 1 0 0imetres ( 1 @ @ ) , thebss < to 1 0 1 0akomeams . < 9 5 1 0 )b ) . and the <rter areatcht in therter ,or , commonually in 0 @ 1 @ .m ( 1 @ 1 0 0 ) . . 1ights @ . @ 5 % 1 @ . @ 5 %g ( 1 @ . @ 5 – 1 @ . @ 5 inb ) , the the birdysomecraft , therter are been <dest unk > , are arecl bell to the to be . and the < of < unk > . < unk > ) . the is be in fem , < , the birdrter , and theidesase the are the ,thing 0 1 0 , the @ .als . the bird isir of the unk > , aed in the <ly and wellgary ,ick <ir , theims . the <st < of a < < unk > " , and the beened in unk > , in theash . . @ . the < th a < <atch in
# -----------------------------------------------------------------------------------------
# | end of epoch  50 | time: 439.30s | valid loss  3.64 | valid ppl    37.98
# -----------------------------------------------------------------------------------------
# | epoch  51 |    50/  332 batches | loss  3.67 | ppl    39.13
# | epoch  51 |   100/  332 batches | loss  3.55 | ppl    34.95
# | epoch  51 |   150/  332 batches | loss  3.56 | ppl    35.09
# | epoch  51 |   200/  332 batches | loss  3.60 | ppl    36.55
# | epoch  51 |   250/  332 batches | loss  3.56 | ppl    35.33
# | epoch  51 |   300/  332 batches | loss  3.57 | ppl    35.36
# =ar , ,assycz =arpiirsasca < as the <an <giteed < starg ofed the a < of < unk > ,site , the < <antic coastcena , <iterraneus <r <s of the < @ . the is aosedly <ative to the <srite , andind < < , the is be in the <ngth of the 0 0 . ( 1 0 km ) , the < of the 0ilomeams . 1 @ 0b ) . and <n a <istiruouslyir , theims . the the , the <rter are commonuen the aing a ,rite ,uc . theache , theerines in the <mer of theing <ygs , are commonry out the <ale . the to 1 < , theirland . , the unk > .vans thearin ,illyar , , a <est <imatedatic inood , and the aidely <atcht in thegter ,ten . andly the the < <ol . the = =ription = = thearin isillyar , is a <ly unk > , the the < ofavegth of to 1 0 0imetres ( 1 0 @ ) , theights < to 1 0 1 0akomeams . < 9 5 1 0 )b ) . and the <rter areatcht in therter ,or , commonually , 0 @ 1 @ .m ( 1 @ 1 0 ) ) . . 1ights @ . @ 5 % 1 @ . @ 5 %g ( 1 @ . @ 5 – 1 @ . @ 5 –b ) , the the birdysome is , therter are been <dle unk > , are arecl bell , the to be . and the < of < unk > . < unk > ) . the is be in fem , < , the birdrter , and theidesasing the are be ,thing 0 1 0 , the @ .als . the bird isir of the unk > , aed in a <ly and wellonary ,ick <ir , theims . the <st < of a < < unk > " , and the beened in unk > , in theysing . @ . the < is a < <atch in
# -----------------------------------------------------------------------------------------
# | end of epoch  51 | time: 515.98s | valid loss  3.63 | valid ppl    37.85
# -----------------------------------------------------------------------------------------
# | epoch  52 |    50/  332 batches | loss  3.67 | ppl    39.06
# | epoch  52 |   100/  332 batches | loss  3.55 | ppl    34.89
# | epoch  52 |   150/  332 batches | loss  3.56 | ppl    35.04
# | epoch  52 |   200/  332 batches | loss  3.60 | ppl    36.51
# | epoch  52 |   250/  332 batches | loss  3.56 | ppl    35.26
# | epoch  52 |   300/  332 batches | loss  3.56 | ppl    35.33
# =ar , ,as anda ,z =arp wasirsa ,a < as the <an <giteed < starg ofed the a < of the unk > ,uite , the < <antic coastcen , <iterraneus <r <s of the < .r the is aosedly <ative to the <srite , andind < < , the is be , the <ngth of the 0 0 . ( 1 0 km ) , the < of the 0ilomeams . 1 @ 0b ) . and <n a <istiruouslyid , theims . the the , the <rter are commonue , and ining a ,rite ,uc . theache , theerines in the <mer of theing <ygs , are commonry out the <ale . the to 1 < , theirland . , the unk > .vanna thearin ,illyar , , a <ly <imatedatic inood , the the aidely <atcht in therter ,ten . andly the the < <ol . the = =ription = = thearm isillyar , is a <ly unk > , the the < ofavegth of to 1 0 0imetres ( 1 0 @ ) , theights < to 1 0 1 0akomeams . 1 9 0 1 0 )b ) . and the <rter areatcht in therter ,or , <ually , 0 @ 1 0 .m ( 1 @ 1 0 0 ) . . 1ights @ . @ 5 % 1 0 . @ 5 %g ( 1 @ . @ 5 – 1 @ . @ 5 inb ) , the the birdyss is , therter are been <dle unk > , are arecl bell , the to be . and the < of < unk > . < unk > ) . the is be in fem , < , the birdrter , and theidesasing the are be ,thing 0 1 0 , thely .als . the < isir of the unk > , aed in a <ly and wellonary ,ical <ir , theims , the <st < of the < < unk > " , and < beened in unk > , in theysing . @ . the < is a < <atch in
# -----------------------------------------------------------------------------------------
# | end of epoch  52 | time: 507.11s | valid loss  3.63 | valid ppl    37.85
# -----------------------------------------------------------------------------------------
# | epoch  53 |    50/  332 batches | loss  3.66 | ppl    38.97
# | epoch  53 |   100/  332 batches | loss  3.55 | ppl    34.84
# | epoch  53 |   150/  332 batches | loss  3.55 | ppl    34.98
# | epoch  53 |   200/  332 batches | loss  3.59 | ppl    36.41
# | epoch  53 |   250/  332 batches | loss  3.56 | ppl    35.17
# | epoch  53 |   300/  332 batches | loss  3.56 | ppl    35.24
# =ar , ,asoracz =arpairiaca < as the <an <giteed < starg ,ed the a < of the unk > ,site , the < <antic coastcena , <iterraneus <r <s of the < .r the is aosely <ative to the <srite of andind < < , the is be from the <ngth of the 0 0 . ( 1 0 km ) , the < of the 0ilomeams . 1 @ 0b ) , and <n a <istir <ouslyir of theims . the the , the <rter are commonue , and ining a <rite ,uc , thede , theerines in the <mer of anding < .gs , are commonry out the <ale . the to 1 < , theirland . , the unk > .omeanna thearus ,illyar , , a <est <imatedatic inood , the the aidely <atcht in thegter ,ten . andly the the < <ol . the = =ription = = thearus isillmar , is a <ly unk > , the the < ofavegth of to 1 0 0imetres ( 1 @ @ ) , theights < to 1 0 1 0akomeams . 1 9 0 1 0 )b ) . and it <rter areatcht in theudter ,t , <ually , 0 @ 1 0 .m ( 1 @ 1 0 ) ) . . 1ights @ . @ 5 % 1 0 . @ 5 %g ( 1 @ . @ 5 – 1 @ . @ 5 inb ) , the the birdysome is , therter are been <dle unk > , are arecl bellge the to be . and the < of < unk > . < unk > ) . the is be in fem , < , the birdrter . and theidesasing the of be ,thing 0 1 0 , thely .als . the < isir of the unk > , aed in a <ly and wellonarysical <ir , theims , the <st < of a < < unk > " , and < beened in unk > , to theysing . @ . it < th a < <atch in
# -----------------------------------------------------------------------------------------
# | end of epoch  53 | time: 511.84s | valid loss  3.63 | valid ppl    37.77
# -----------------------------------------------------------------------------------------
# | epoch  54 |    50/  332 batches | loss  3.66 | ppl    38.93
# | epoch  54 |   100/  332 batches | loss  3.55 | ppl    34.80
# | epoch  54 |   150/  332 batches | loss  3.55 | ppl    34.92
# | epoch  54 |   200/  332 batches | loss  3.59 | ppl    36.34
# | epoch  54 |   250/  332 batches | loss  3.56 | ppl    35.11
# | epoch  54 |   300/  332 batches | loss  3.56 | ppl    35.21
# =ar , ,asingapz =arpaaiiaca < as the <an <utered < starbs ,ed and a < of < unk > ,s .ed the < <antic coastcen , <iterraneus <r <s of the < . , the is aosely <ative to the <srter of andind < < , the is be from the <ngth of the 0 0 . ( 1 0 km ) , the < of the 0ilomeams . 1 @ 0b ) , and <n a <istiruouslyid , cerims . the the , the <rter are commonue @ and ining a <rite ,uc , thede , theer ,s in the <mer of anding <ygs , are <ried out the <ale . the to 1 < , theirland . . the unk > .omeanna thearus ,illyar , , a <est <imatedatic inood , and the aidely <atcht in theyter .ten . andly the the < <ol . the = =ription = = thearin isillyar , is a <ly unk > of the the < ofavesgth of to 1 0 0imetres ( 1 @ @ ) , theights < to 1 0 1 0akomeam . . 1 9 0 1 0 )b ) . and it <rter isatcht in theyter ,et , <ually , 0 @ 1 0 @m ( 1 @ 1 0 ) ) , . 1ights @ . @ 5 % 1 @ . @ 5 %g ( 1 @ . @ 5 – 1 @ . @ 5 inb ) , the the birdyss of , therter ( been <dle unk > , is arecl bellge the to be . and the < of < unk > , < unk > ) . the is be in bird , < , the birdrter , and theidesasing the of be ,thing 0 1 0 , thely .als . the < isir of the unk > , aed in a <ly and wellonarymical <ir , <ims , the <st < of a < < unk > " , and < beened by unk > , in theying . @ . it < th a < < . in
# -----------------------------------------------------------------------------------------
# | end of epoch  54 | time: 523.91s | valid loss  3.63 | valid ppl    37.86
# -----------------------------------------------------------------------------------------
# | epoch  55 |    50/  332 batches | loss  3.67 | ppl    39.06
# | epoch  55 |   100/  332 batches | loss  3.55 | ppl    34.84
# | epoch  55 |   150/  332 batches | loss  3.55 | ppl    34.93
# | epoch  55 |   200/  332 batches | loss  3.59 | ppl    36.32
# | epoch  55 |   250/  332 batches | loss  3.56 | ppl    35.05
# | epoch  55 |   300/  332 batches | loss  3.56 | ppl    35.17
# =ar , ,ainediaiaz =arpzyiaia , < as the <an ofrtered < starbs ,ed and a < of the unk > ,ster , the < <antic coastmna , whichiterraneus ,r <s of the < . , the is aose to <ative to the < <rter , andind < < , the is have from be <ngth of the 0 0m ( 1 0 km ) , the < of the 0ilomeams . 1 9 0b ) , and <n a <istir ,ouslyir , theims . the the , the <yter are oftenuely and ining a <gite ,uc , thede , theer ,s in the <mer of anding maygs , are <ry out the <ale . the to 1 < , theirland . , the unk > .vans thearus ,illudar , , a <ly commonimatedatic inood , and the aidely <atcht in thegter .t . andly the the < andol . the = =ription = = thearusiahdar , is a <ly unk > , and the < ofavesgth of to 1 0 0imetres ( 1 0 ° ) , theights < to 1 0 1 0akomeams . 1 9 0 1 0 )b ) , and it <rter areatcht in theudter ,t , <ually in 0 0 1 0 .m ( 1 @ 1 0 ) ) , . 1ights @ . @ 5 in 1 0 . @ 5 %g ( 1 @ . @ 5 in 1 @ . @ 5 inb ) , the the birdysome , , theudter ( been <dle unk > , are arecl bellge the to be . and the < of < unk > , < unk > ) , the is be in fem , < , the birdyter , and theidesasing the of be ,thing 0 1 0 , thely .als . the < isir of the unk > , aed in a <ly and wellonarymical <ir , theims , the <st < of a < < unk > " , and < beened by unk > , in theying .y . the < is a < < . in
# -----------------------------------------------------------------------------------------
# | end of epoch  55 | time: 469.69s | valid loss  3.63 | valid ppl    37.89
# -----------------------------------------------------------------------------------------
# | epoch  56 |    50/  332 batches | loss  3.66 | ppl    38.82
# | epoch  56 |   100/  332 batches | loss  3.55 | ppl    34.75
# | epoch  56 |   150/  332 batches | loss  3.55 | ppl    34.82
# | epoch  56 |   200/  332 batches | loss  3.59 | ppl    36.21
# | epoch  56 |   250/  332 batches | loss  3.55 | ppl    34.95
# | epoch  56 |   300/  332 batches | loss  3.56 | ppl    35.08
# =ar , ,ianiaiaz =arp wasaiiaia , < as the <an ofudter , < starr , , the a < of the unk > ,ster , the < <antic coastmna , whichiterraneus ,r <s of the < @ , the is aose to <ative to the < <rter of andind < < , the is have from be <ngth of the 0 0m ( 1 0 km ) , the < of the 0gomeams . 1 9 0b ) , and <n a <istir ,ous speciesir , theims . the the , the <yter are alsoock @ and toing a <gite , . , thede , theer <s in the <mer of anding <ygs , are <ry out the <ale . the to 1 < , theirland . , the unk > .vans thearus ,illudar , , a <est commonimateded toood , and the aidely <atcht in thegter .ten . andly the the < <ol . the = =ription = = thearmer ishdar , is a <ly unk > , and the < ofngth of to 1 0 0imetres ( 1 0 @ ) , theights < to 1 0 1 0akomeam . . 1 @ 0 1 0 )b ) , and it <yter areatcht in theyter ,ten , <ually in 0 @ 1 0 .m ( 1 @ 1 6 ) ) , . 1ights @ . @ 5 in 1 0 . @ 5 ing ( 1 @ . @ 5 in 1 @ . @ 5 inb ) , the the birdysome , , therter are been <dle unk > , are arecl bellge the to be . and the < of < unk > , < unk > ) , the is be in other , < , the birdyter , and theidesasing the are be ,thing 0 1 0 , the , .als . the < isir of the unk > , aed in the <ly and wellonalmical <ir , theims , the <st < of a < < unk > " , and the beened by unk > , to theyed .y . the < is a < < . in
# -----------------------------------------------------------------------------------------
# | end of epoch  56 | time: 519.53s | valid loss  3.63 | valid ppl    37.85
# -----------------------------------------------------------------------------------------
# | epoch  57 |    50/  332 batches | loss  3.66 | ppl    38.72
# | epoch  57 |   100/  332 batches | loss  3.55 | ppl    34.65
# | epoch  57 |   150/  332 batches | loss  3.55 | ppl    34.77
# | epoch  57 |   200/  332 batches | loss  3.59 | ppl    36.14
# | epoch  57 |   250/  332 batches | loss  3.55 | ppl    34.91
# | epoch  57 |   300/  332 batches | loss  3.56 | ppl    35.05
# =ar , ,ainedia ,z =ar < wasaiia ,z the as the <an ofrter , < starg of , the a < of the unk > ,ster , the < <antic coastmna , whichiterrayeus ,r <s of the < @ , the is aosed to <ative to the < <rter , andind < < , the is have from be <ngth of the 0 %m ( 1 0 km ) , the < of the 0ilomeams . 1 @ 0b ) , and <n a <istir <ous speciesir , theims . the the , the birdyter are oftenockn and toing a <gite ,uc , thede , theerines in the <mer of anding <ygs , are <ry out the <ale . the to 1 < , theirland . , the unk > .vans thearin isilludar , is a <ly commonimateded toood , and the aidely <atcht in thegter .ten . andly the the < <ol . the = =ription = = thearmer isillsar , is a <ly unk > , and the < ofavegthus to 1 0 0imetres ( 1 0 ft ) , theights < to 1 @ 1 0gomeams . 1 @ 0 1 0 )b ) , and it <rter areatcht in theudter ,t , <ually in 0 @ 1 0 @m ( 1 @ 1 0 ) ) , . 1ighted @ . @ 5 % 1 0 . @ 5 %g ( 1 @ . @ 5 – 1 @ . @ 5 %b ) , the the birdysome , , therter are been <bole unk > , are arecl bellge the to be . and the < of < unk > , < unk > ) , the is be in fem , < later the birdyter , and theidesasing the are be morething 0 1 0 , the , .als . the bird isir of the unk > , aed , a < < and wellnalmical <ir , theims . the <st < of a most < unk > " , and the beened to unk > , to theyed . @ . the < is a most < . in
# -----------------------------------------------------------------------------------------
# | end of epoch  57 | time: 484.13s | valid loss  3.63 | valid ppl    37.62
# -----------------------------------------------------------------------------------------
# | epoch  58 |    50/  332 batches | loss  3.65 | ppl    38.59
# | epoch  58 |   100/  332 batches | loss  3.54 | ppl    34.59
# | epoch  58 |   150/  332 batches | loss  3.55 | ppl    34.74
# | epoch  58 |   200/  332 batches | loss  3.59 | ppl    36.06
# | epoch  58 |   250/  332 batches | loss  3.55 | ppl    34.84
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 9
#       7 for epoch in range(1, epochs + 1):
#       8     epoch_start_time = time.time()
# ----> 9     train(model)
#      10     val_loss = evaluate(model, val_data)
#      11     val_ppl = math.exp(min(val_loss, 100 ))
#
# Cell In[6], line 28, in train(model)
#      25 #torch.nn.utils.clip_grad_norm_(model.parameters(), 0.5)
#      26 optimizer.step()
# ---> 28 total_loss += loss.item()
#      29 if batch % log_interval == 0 and batch > 0:
#      30     #lr = scheduler.get_last_lr()[0]
#      31     ms_per_batch = (time.time() - start_time) * 1000 / log_interval
#
# KeyboardInterrupt:

# %% [markdown]
# ## Evaluate the best model on the test dataset

# %%
test_loss = evaluate(model, test_data)
test_ppl = math.exp(test_loss)
print('=' * 89)
print(f'| End of training | test loss {test_loss:5.2f} | '
      f'test ppl {test_ppl:8.2f}')
print('=' * 89)
